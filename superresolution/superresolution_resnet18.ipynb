# %%
import numpy as np
import tensorflow as tf
import keras
import cv2
from keras.layers import MaxPool2D,Conv2D,UpSampling2D,Input,Dropout
from keras.models import Sequential
from tensorflow.keras.utils import img_to_array
import os
from tqdm import tqdm
import re
import matplotlib.pyplot as plt

# %%
import pickle
with open('../DATA/super_res/super_res_array.pickle','rb') as f:
    img_array = pickle.load(f)

# %%
from sklearn.model_selection import train_test_split 

all_images = np.array(img_array)

#Split test and train data. all_images will be our output images
train_x, test_x = train_test_split(all_images, random_state = 32, test_size=0.2)

# %%
#now we will make input images by lowering resolution without changing the size
def pixalate_image(image, scale_percent = 20):
    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    dim = (width, height)
    small_image = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
  
    # scale back to original size
    width = int(small_image.shape[1] * 100 / scale_percent)
    height = int(small_image.shape[0] * 100 / scale_percent)
    dim = (width, height)
    low_res_image = cv2.resize(small_image, dim, interpolation =  cv2.INTER_AREA)
    return low_res_image

# %%
train_x_px = []
for i in range(train_x.shape[0]):
    temp = pixalate_image(train_x[i,:,:,:])
    train_x_px.append(temp)
    
train_x_px = np.array(train_x_px)   #Distorted images
# get low resolution images for the validation set
test_x_px = []
for i in range(test_x.shape[0]):
    temp = pixalate_image(test_x[i,:,:,:])
    test_x_px.append(temp)
    
test_x_px = np.array(test_x_px)     #Distorted images

# %%
train_x_px.shape
# Out:
# (10586, 160, 160, 3)

# %%
from AE_RESNET.resnetAE import ResNetAE

# %%
resnet18AE = ResNetAE(input_shape=(160,160,3), output_channels=3, resnet_decoder=True)
resnet18AE.summary()
# Out:
# Model: "ResNetAE"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 160, 160, 3)]     0
#
#  ResNet_encoder (Functional)  (None, 5, 5, 512)        12604352
#
#  ResNet_decoder (Functional)  (None, 160, 160, 3)      17248911
#
# =================================================================
# Total params: 29,853,263
# Trainable params: 29,833,929
# Non-trainable params: 19,334
# _________________________________________________________________

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.0005)
resnet18AE.compile(optimizer=optimizer, loss="mse")

early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = resnet18AE.fit(
    train_x_px,
    train_x,
    epochs=30,
    batch_size=80, 
    shuffle=True,
    validation_split=0.1, 
    callbacks=[early_stopping]
    )
# Out:
# Epoch 1/30
# 120/120 [==============================] - 69s 482ms/step - loss: 0.0427 - val_loss: 0.0426
# Epoch 2/30
# 120/120 [==============================] - 56s 465ms/step - loss: 0.0242 - val_loss: 0.0361
# Epoch 3/30
# 120/120 [==============================] - 53s 442ms/step - loss: 0.0190 - val_loss: 0.0212
# Epoch 4/30
# 120/120 [==============================] - 55s 460ms/step - loss: 0.0157 - val_loss: 0.0203
# Epoch 5/30
# 120/120 [==============================] - 55s 459ms/step - loss: 0.0133 - val_loss: 0.0098
# Epoch 6/30
# 120/120 [==============================] - 56s 464ms/step - loss: 0.0114 - val_loss: 0.0142
# Epoch 7/30
# 120/120 [==============================] - 54s 450ms/step - loss: 0.0101 - val_loss: 0.0079
# Epoch 8/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0087 - val_loss: 0.0075
# Epoch 9/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0078 - val_loss: 0.0098
# Epoch 10/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0070 - val_loss: 0.0102
# Epoch 11/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0065 - val_loss: 0.0141
# Epoch 12/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0059 - val_loss: 0.0117
# Epoch 13/30
# 120/120 [==============================] - 53s 442ms/step - loss: 0.0055 - val_loss: 0.0067
# Epoch 14/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0051 - val_loss: 0.0083
# Epoch 15/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0049 - val_loss: 0.0159
# Epoch 16/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0045 - val_loss: 0.0054
# Epoch 17/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0043 - val_loss: 0.0044
# Epoch 18/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0041 - val_loss: 0.0071
# Epoch 19/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0039 - val_loss: 0.0056
# Epoch 20/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0037 - val_loss: 0.0064
# Epoch 21/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0036 - val_loss: 0.0050
# Epoch 22/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0035 - val_loss: 0.0043
# Epoch 23/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0033 - val_loss: 0.0082
# Epoch 24/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0033 - val_loss: 0.0065
# Epoch 25/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0032 - val_loss: 0.0079
# Epoch 26/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0032 - val_loss: 0.0048
# Epoch 27/30
# 120/120 [==============================] - 53s 441ms/step - loss: 0.0030 - val_loss: 0.0048

# %%
predictions = resnet18AE.predict(test_x_px)
n = 8
plt.figure(figsize= (20,10))
for i in range(n):
    ax = plt.subplot(3, n, i+1)
    plt.imshow(test_x_px[i+3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(3, n, i+1+n)
    plt.imshow(predictions[i+3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    ax = plt.subplot(3, n, i+1+n+n)
    plt.imshow(test_x[i+3])
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 83/83 [==============================] - 7s 60ms/step

# %%
# ssim score
ssim = tf.image.ssim(test_x, predictions, max_val=1.0)
ssim = tf.reduce_mean(ssim)
print('SSIM Score:',ssim)

# psnr score
psnr = tf.image.psnr(test_x, predictions, max_val=1.0)
psnr = tf.reduce_mean(psnr)
print('PSNR Score:',psnr)

#mse score
mse = tf.keras.losses.mean_squared_error(test_x, predictions)
mse = tf.reduce_mean(mse)
print('MSE Score:',mse)
# Out:
# SSIM Score: tf.Tensor(0.72503805, shape=(), dtype=float32)
# PSNR Score: tf.Tensor(23.990952, shape=(), dtype=float32)
# MSE Score: tf.Tensor(0.0042787106, shape=(), dtype=float32)

# %%
resnet18AE.save('final_models/resnet18AE.h5')

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_lr(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

# %%
plot_lr(history)
